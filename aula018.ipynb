# %%
teste = list()
teste.append('Gustavo')
teste.append(40)

galera = list()
galera.append(teste[:])#copia de teste

teste[0] = 'Maria'
teste[1] = 22
galera.append(teste[:])
print(galera)

# %%
galera = [['João', 19], ['Ana', 33], ['Joaquim', 12], ['Maria', 45]]
print(galera)#todos os dados
print('-=' * 20)
print(galera[3][0])#Só os itens selecionados.

# %%
#Usando o 'FOR'
galera = [['João', 19], ['Ana', 33], ['Joaquim', 12], ['Maria', 45]]
for pessoa in galera:
    print(pessoa)

# %%
#Selecionar apenas os 'NOMES'
galera = [['João', 19], ['Ana', 33], ['Joaquim', 12], ['Maria', 45]]
for pessoa in galera:
    print(pessoa[0])

# %%
#Usando print formatado
galera = [['João', 19], ['Ana', 33], ['Joaquim', 12], ['Maria', 45]]
for pessoa in galera:
    print(f'{pessoa[0]} tem {pessoa[1]} anos de idade.')

# %%
#Usando 'INPUT'
galera = list()
dado = list()
for cont in range(0, 3):
    dado.append(str(input('Nome: ')))
    dado.append(int(input('Idade: ')))
    galera.append(dado[:])#copia dos dados.
    dado.clear()#limpa os dados.
print(galera)

# %%
galera = list()
dado = list()
totalmaior = totalmenor = 0
for cont in range(0, 3):
    dado.append(str(input('Nome: ')))
    dado.append(int(input('Idade: ')))
    galera.append(dado[:])
    dado.clear()
for pessoa in galera:
    if pessoa[1] >= 18:
        print(f'{pessoa[0]} é maior de idade.')
        totalmaior += 1
    else:
        print(f'{pessoa[0]} é menor de idade.')
        totalmenor += 1
print(f'Temos {totalmaior} maiores e {totalmenor} menores de idade.')
