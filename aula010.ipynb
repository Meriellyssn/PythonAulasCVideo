# %%
'''nome = str(input('Qual é seu nome: '))
if nome == 'Meirielli':
    print('Que nome lindo você tem!')#quando a estrutura tem apenas o (if) é uma estrutura condicional simples!
else:
    print('Seu nome é tão normal!')
print('Bom dia, {}!'.format(nome))#Quando a estrutura tem o (else) é uma estrutura condicional composta.'''

print('-' * 20)
n1 = float(input('Digite a primeira nota: '))
n2 = float(input('Digite a segunda nota: '))
m = (n1 + n2)/2
print('Média >>> {:.1f}'.format(m))
'''if m >= 7:
    print('Sua média foi boa! PARABÉNS!')
else:
    print('Sua média não foi boa! ESTUDE MAIS!')'''

print('PARABÉNS!' if m >= 7 else 'ESTUDE MAIS!')#comando simplificado em uma linha.
