# %%
#Criando Docstrings

def contador(i, f, p):
    """
    -> Faz uma contagem e mostra na tela.
    :param i: início da contagem
    :param f: fim da contagem
    :param p: passo da contagem
    :return: sem retorno
    Função criada por Gustavo Guanabara do canal CursoemVideo.
    """
    c = i
    while c <= f:
        print(f'{c} ', end='')
        c += p
    print('FIM!')

help(contador)
# Out:
# Help on function contador in module __main__:
#
# contador(i, f, p)
#     -> Faz uma contagem e mostra na tela.
#     :param i: início da contagem
#     :param f: fim da contagem
#     :param p: passo da contagem
#     :return: sem retorno
#     Função criada por Gustavo Guanabara do canal CursoemVideo.

# %%
#Parâmetros Opcionais

def somar(a=0, b=0, c=0): # <- aqui estamos atribuindo o parâmetro opcional.
    '''
    -> Faz a soma de três valores e mostra o resultado ba tela.
    :param a: o primeiro valor.
    :param b: o segundo valor.
    :param c: o terceiro valor.
    :return: sem retorno
    Função criada para aula no cursoemvideo.
    '''

    s = a + b + c
    print(f'A soma vale {s}')

somar(3, 3, 7)
# Out:
# A soma vale 13

# %%
#Escopo de variáveis

def teste():
    x = 8 #-> 'x' é uma variável local.
    print(f'Na função teste, n vale {n}.')
    print(f'Na função teste, x vale {x}.')

#Programa principal
n = 2 #-> 'n' é uma variável global.
print(f'No programa principal, n vale {n}.')
#print(f'No programa principal, x vale {x}.') -> essa função não funciona porque o 'x' é uma variával local, que esta sendo chamada fora de seu escopo.
teste()
# Out:
# No programa principal, n vale 2.
# Na função teste, n vale 2.
# Na função teste, x vale 8.

# %%
def teste(b):
    a = 8
    b += 4
    c = 2
    print(f'A - local vale {a}.')
    print(f'B - local vale {b}.')
    print(f'C - local vale {c}.')

a = 5
teste(a)
print(f'A - global vale {a}.')
# Out:
# A - local vale 8.
# B - local vale 9.
# C - local vale 2.
# A - global vale 5.

# %%
def teste(b):
    global a # -> definindo a variável local como global.
    a = 8 # -> passa a ser uma variável global.
    b += 4
    c = 2
    print(f'A - local vale {a}.')
    print(f'B - local vale {b}.')
    print(f'C - local vale {c}.')

a = 5 # -> Essa variável é apagada.
teste(a)
print(f'A - global vale {a}.')
# Out:
# A - local vale 8.
# B - local vale 9.
# C - local vale 2.
# A - global vale 8.

# %%
#Retornando valores 'return'

def somar(a=0, b=0, c=0):
    s = a + b + c
    return s

r1 = somar(3, 2, 5)
r2 = somar(2, 2)
r3 = somar(6)
print(f'Meus cálculos deram {r1}, {r2} e {r3}.')
# Out:
# Meus cálculos deram 10, 4 e 6.

# %%
#Exercício prático 01

def fatorial(num=1):
    f = 1
    for c in range(num, 0, -1):
        f *= c
    return f

n = int(input('Digite um número: '))
print(f'O fatorial de {n} é igual a {fatorial(n)}')
# Out:
# O fatorial de 5 é igual a 120

# %%
#Exercício prático 02

def fatorial(num=1):
    f = 1
    for c in range(num, 0, -1):
        f *= c
    return f

f1 = fatorial(5)
f2 = fatorial(4)
f3 = fatorial()
print(f'Os resultados foram {f1}, {f2} e {f3}.')
# Out:
# Os resultados foram 120, 24 e 1.

# %%
#Exercício prático 03

def par(n=0):
    if n % 2 == 0:
        return True
    else:
        return False

num = int(input('Digite um número: '))
print(par(num))
# Out:
# False

# %%
#Exercício prático 04

def par(n=0):
    if n % 2 == 0:
        return True
    else:
        return False

num = int(input('Digite um número: '))
if par(num):
    print('É par!')
else:
    print('Não é par!')
# Out:
# É par!
