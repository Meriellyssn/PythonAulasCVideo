# %%
#Nessa aula, vamos começar nossos estudos com os laços e
# vamos fazer primeiro o “for”, que é uma estrutura
# versátil e simples de entender. Por exemplo:

'''for c in range(0, 6):#repete 6 vezes
    print('Oi')
print('fim!')
print('-=' * 15)
for c in range(0,6):#contagem crescente de 0 a 5.
    print(c)
print('fim!')
print('-=' * 15)
for c in range(6, 0, -1):#contagem regressiva.
    print(c)
print('fim!')
print('-=' * 15)
for c in range(0, 6, 2):#contagem crescente, pulando de 2 em 2.
    print(c)
print('fim!')
print('-=' * 15)'''

'''n = int(input('Digite um número: '))
for c in range(0, n+1):
    print(c)
print('fim!')'''

'''i = int(input('Inicio: '))
f = int(input('Fim: '))
p = int(input('Passo: '))
for c in range(i, f+1, p):
    print(c)
print('fim!')'''

s = 0
for c in range(0, 3):
    n = int(input('Digite um valor: '))
    s += n
print('A soma de todos os valores foi >> {} <<.'.format(s))
